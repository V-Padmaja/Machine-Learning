# %% [markdown]
# **Padmaja - 19BAI1107 : Pandas 2b**

# %%
import pandas as pd

# %% [markdown]
# **Dislaying dimensions of the dataset ( no of rows and columns)**

# %%
df1 = pd.read_csv('Housing.csv') 
df1.shape
# Out:
# (545, 13)

# %% [markdown]
# **Displaying the dataset**

# %%
df1
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %% [markdown]
# **First 5 rows of df1**

# %%
df1.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %% [markdown]
# **First 10 rows of df1**

# %%
df1.head(10)
# Out:
#       price   area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000   7420         4          2        3      yes        no       no
# 1  12250000   8960         4          4        4      yes        no       no
# 2  12250000   9960         3          2        2      yes        no      yes
# 3  12215000   7500         4          2        2      yes        no      yes
# 4  11410000   7420         4          1        2      yes       yes      yes
# 5  10850000   7500         3          3        1      yes        no      yes
# 6  10150000   8580         4          3        4      yes        no       no
# 7  10150000  16200         5          3        2      yes        no       no
# 8   9870000   8100         4          1        2      yes       yes      yes
# 9   9800000   5750         3          2        4      yes       yes       no
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# ...

# %% [markdown]
# **Last 5 rows of df1**

# %%
df1.tail()
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 540  1820000  3000         2          1        1      yes        no      yes
# 541  1767150  2400         3          1        1       no        no       no
# 542  1750000  3620         2          1        1      yes        no       no
# 543  1750000  2910         3          1        1       no        no       no
# 544  1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 540              no              no        2       no      unfurnished
# 541              no              no        0       no   semi-furnished
# 542              no              no        0       no      unfurnished
# 543              no              no        0       no        furnished
# 544              no              no        0       no      unfurnished

# %% [markdown]
# **Converting dataframe (df1) to csv file**

# %%
df1.to_csv('housing_dataframeToFile.csv')

# %% [markdown]
# **Viewing price column of df1**

# %%
df1['price']
# Out:
# 0      13300000
# 1      12250000
# 2      12250000
# 3      12215000
# 4      11410000
#          ...
# 540     1820000
# 541     1767150
# 542     1750000
# 543     1750000
# 544     1750000
# Name: price, Length: 545, dtype: int64

# %% [markdown]
# **Viewig price and bedrooms column of df1**

# %%
df1[['price','bedrooms']]
# Out:
#         price  bedrooms
# 0    13300000         4
# 1    12250000         4
# 2    12250000         3
# 3    12215000         4
# 4    11410000         4
# ..        ...       ...
# 540   1820000         2
# 541   1767150         3
# 542   1750000         2
# 543   1750000         3
# 544   1750000         3
#
# [545 rows x 2 columns]

# %% [markdown]
# **Setting price as index of df1**

# %%
df1.set_index("price")
df1.head(4)
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished

# %% [markdown]
# **Replacing index column from series of number to price**

# %%
df1.set_index("price",inplace=True)
df1.head(3)
# Out:
#           area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# price
# 13300000  7420         4          2        3      yes        no       no
# 12250000  8960         4          4        4      yes        no       no
# 12250000  9960         3          2        2      yes        no      yes
#
#          hotwaterheating airconditioning  parking prefarea furnishingstatus
# price
# 13300000              no             yes        2      yes        furnished
# 12250000              no             yes        3       no        furnished
# 12250000              no              no        2      yes   semi-furnished

# %% [markdown]
# **Resetting index to series of nos**

# %%
df1.reset_index(inplace=True)
df1.head(3)
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished

# %% [markdown]
# **Returning datatype of columns**

# %%
type(df1['bedrooms'])
# Out:
# pandas.core.series.Series

# %%
type(df1['bathrooms'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# **Adding a new column**

# %%
df1['no_of_rooms']=df1['bedrooms']+df1['bathrooms']

# %%
df1
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# 5    10850000  7500         3          3        1      yes        no      yes
# 6    10150000  8580         4          3        4      yes        no       no
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %% [markdown]
# **Dropping a column**

# %%
df1.drop('no_of_rooms',axis=1)
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# 5    10850000  7500         3          3        1      yes        no      yes
# 6    10150000  8580         4          3        4      yes        no       no
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %% [markdown]
# **Consice summary of dataframe**

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 543 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             543 non-null    int64
#  1   area              543 non-null    int64
#  2   bedrooms          543 non-null    int64
#  3   bathrooms         543 non-null    int64
#  4   stories           543 non-null    int64
#  5   mainroad          543 non-null    object
#  6   guestroom         543 non-null    object
#  7   basement          543 non-null    object
#  8   hotwaterheating   543 non-null    object
#  9   airconditioning   543 non-null    object
#  10  parking           543 non-null    int64
#  11  prefarea          543 non-null    object
#  12  furnishingstatus  543 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 79.4+ KB

# %% [markdown]
# **Dropping a few columns and viewing the first 10 rows** Columns 1 and 3 have been dropped earlier

# %%
df1.drop(7,axis=0,inplace=True)

# %%
df1.drop(9,axis=0,inplace=True)
df1.head(10)
# Out:
#     Price of house   area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0         13300000   7420         4          2        3      yes        no
# 2         12250000   9960         3          2        2      yes        no
# 4         11410000   7420         4          1        2      yes       yes
# 5         10850000   7500         3          3        1      yes        no
# 6         10150000   8580         4          3        4      yes        no
# 8          9870000   8100         4          1        2      yes       yes
# 10         9800000  13200         3          1        2      yes        no
# 11         9681000   6000         4          3        2      yes       yes
# 12         9310000   6550         4          2        2      yes        no
# 13         9240000   3500         4          2        2      yes        no
#
#    basement hotwaterheating airconditioning  parking prefarea furnishingstatus
# ...

# %% [markdown]
# **Selecting rows based on label. Label here is 5**

# %%
df1.loc[5]
# Out:
# price                     10850000
# area                          7500
# bedrooms                         3
# bathrooms                        3
# stories                          1
# mainroad                       yes
# guestroom                       no
# basement                       yes
# hotwaterheating                 no
# airconditioning                yes
# parking                          2
# prefarea                       yes
# furnishingstatus    semi-furnished
# Name: 5, dtype: object

# %% [markdown]
# **Selecting rows based on position.Position here is 3**

# %%
df1.iloc[3]
# Out:
# price                     10850000
# area                          7500
# bedrooms                         3
# bathrooms                        3
# stories                          1
# mainroad                       yes
# guestroom                       no
# basement                       yes
# hotwaterheating                 no
# airconditioning                yes
# parking                          2
# prefarea                       yes
# furnishingstatus    semi-furnished
# Name: 5, dtype: object

# %% [markdown]
# **Type of dataframe**

# %%
print("Type:\n",type(df1))
# Out:
# Type:
#  <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# **Rows and columns in dataframe after dropping duplicates**

# %%
print("Shape of dataframe:",df1.shape)
df1.drop_duplicates()
print(df1.shape)
# Out:
# Shape of dataframe: (543, 13)
# (543, 13)

# %% [markdown]
# **All columns of dataframe**

# %%
print("Columns of dataframe:\t",df1.columns)
# Out:
# Columns of dataframe:	 Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %% [markdown]
# **Renaming price column of dataframe**

# %%
df1.rename(columns={'price':'Price of house'},inplace=True)
print("Columns of dataframe:\t",df1.columns)
# Out:
# Columns of dataframe:	 Index(['Price of house', 'area', 'bedrooms', 'bathrooms', 'stories',
#        'mainroad', 'guestroom', 'basement', 'hotwaterheating',
#        'airconditioning', 'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %% [markdown]
# **Basic statistical details of dataframe**

# %%
print(df1.describe())
# Out:
#        Price of house          area    bedrooms   bathrooms     stories  \
# count    5.430000e+02    543.000000  543.000000  543.000000  543.000000
# mean     4.739231e+06   5139.198895    2.961326    1.279926    1.801105
# std      1.817972e+06   2165.595105    0.736737    0.488712    0.863913
# min      1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%      3.430000e+06   3592.000000    2.000000    1.000000    1.000000
# 50%      4.340000e+06   4560.000000    3.000000    1.000000    2.000000
# 75%      5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max      1.330000e+07  16200.000000    6.000000    3.000000    4.000000
#
#           parking
# count  543.000000
# mean     0.685083
# std      0.851685
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %% [markdown]
# **Indexing and obtaining fields**

# %%
print("First five values of 'Price' column\t:\n",df1.iloc[0:5,4:7])
# Out:
# First five values of 'Price' column	:
#     stories mainroad guestroom
# 0        3      yes        no
# 2        2      yes        no
# 4        2      yes       yes
# 5        1      yes        no
# 6        4      yes        no

# %% [markdown]
# **Creating subsets using relational operators**

# %%
df2 = df1['area']>5000
print(df2)
# Out:
# 0       True
# 2       True
# 4       True
# 5       True
# 6       True
#        ...
# 540    False
# 541    False
# 542    False
# 543    False
# 544    False
# Name: area, Length: 543, dtype: bool

# %%
df3 = df1[df2]
print(df3)
# Out:
#      Price of house  area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0          13300000  7420         4          2        3      yes        no
# 2          12250000  9960         3          2        2      yes        no
# 4          11410000  7420         4          1        2      yes       yes
# 5          10850000  7500         3          3        1      yes        no
# 6          10150000  8580         4          3        4      yes        no
# ..              ...   ...       ...        ...      ...      ...       ...
# 487         2870000  5400         4          1        2      yes        no
# 488         2852500  5200         4          1        3      yes        no
# 494         2730000  6800         2          1        1      yes        no
# 520         2450000  7700         2          1        1      yes        no
# 531         2233000  5300         3          1        1       no        no
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %% [markdown]
# **Grouping dataframe by values in furnishing**

# %%
df5 = df1.groupby('furnishingstatus').mean()
df5
# Out:
#                   Price of house         area  bedrooms  bathrooms   stories  \
# furnishingstatus
# furnished           5.398061e+06  5651.260870  3.050725   1.355072  1.927536
# semi-furnished      4.907524e+06  5166.339207  3.008811   1.303965  1.801762
# unfurnished         4.013831e+06  4707.595506  2.831461   1.191011  1.702247
#
#                    parking
# furnishingstatus
# furnished         0.855072
# semi-furnished    0.735683
# unfurnished       0.488764

# %% [markdown]
# **Scatter plot od area vs price of house**

# %%
df1.plot(x='area',y='Price of house',kind='scatter')
