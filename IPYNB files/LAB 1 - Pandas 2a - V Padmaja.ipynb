# %% [markdown]
# **Padmaja - 19BAI1107 Pandas 2a**

# %%
import pandas as pd

# %%
regno = ['XX0001','XX0002','XX0003','XX0004']
Sub1 = [89,90,78,98]
Sub2 = [67,90,100,100]
Sub3 = [78,89,90,89]

titles = ['RegistrationNumber', 'Mark1','Mark2','Mark3']
values = [regno,Sub1,Sub2,Sub3]
result = list(zip(titles,values))
result
# Out:
# [('RegistrationNumber', ['XX0001', 'XX0002', 'XX0003', 'XX0004']),
#  ('Mark1', [89, 90, 78, 98]),
#  ('Mark2', [67, 90, 100, 100]),
#  ('Mark3', [78, 89, 90, 89])]

# %%
result1 = dict(result)
df1 = pd.DataFrame(result1)
print(df1)
# Out:
#   RegistrationNumber  Mark1  Mark2  Mark3
# 0             XX0001     89     67     78
# 1             XX0002     90     90     89
# 2             XX0003     78    100     90
# 3             XX0004     98    100     89

# %%
df2 = pd.read_csv('nyc_weather.csv')
df2.shape
# Out:
# (31, 11)

# %%
df2
# Out:
#            EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0   01-01-2016           38        23        52                 30.03
# 1   01-02-2016           36        18        46                 30.02
# 2   01-03-2016           40        21        47                 29.86
# 3   01-04-2016           25         9        44                 30.05
# 4   01-05-2016           20        -3        41                 30.57
# 5   01-06-2016           33         4        35                 30.50
# 6   01-07-2016           39        11        33                 30.28
# 7   01-08-2016           39        29        64                 30.20
# 8   01-09-2016           44        38        77                 30.16
# 9   01-10-2016           50        46        71                 29.59
# 10  01-11-2016           33         8        37                 29.92
# 11  01-12-2016           35        15        53                 29.85
# ...

# %%
df2.head()
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  01-01-2016           38        23        52                 30.03
# 1  01-02-2016           36        18        46                 30.02
# 2  01-03-2016           40        21        47                 29.86
# 3  01-04-2016           25         9        44                 30.05
# 4  01-05-2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
df2.head(7)
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  01-01-2016           38        23        52                 30.03
# 1  01-02-2016           36        18        46                 30.02
# 2  01-03-2016           40        21        47                 29.86
# 3  01-04-2016           25         9        44                 30.05
# 4  01-05-2016           20        -3        41                 30.57
# 5  01-06-2016           33         4        35                 30.50
# 6  01-07-2016           39        11        33                 30.28
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
# ...

# %%
df2.tail()
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 26  1/27/2016           41        22        45                 30.03
# 27  1/28/2016           37        20        51                 29.90
# 28  1/29/2016           36        21        50                 29.58
# 29  1/30/2016           34        16        46                 30.01
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 26               10           7.0               T           3   Rain
# 27               10           5.0               0           1    NaN
# 28               10           8.0               0           4    NaN
# 29               10           7.0               0           0    NaN
# 30               10           5.0               0           0    NaN
#
#     WindDirDegrees
# 26             311
# 27             234
# 28             298
# 29             257
# 30             241

# %%
df2.head(2)
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  01-01-2016           38        23        52                 30.03
# 1  01-02-2016           36        18        46                 30.02
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
#
#    WindDirDegrees
# 0             281
# 1             275

# %%
df2.shape
# Out:
# (31, 11)

# %%
df2.to_csv('nyc_weather_dataframeToFile.csv')

# %%
df2['Temperature']
# Out:
# 0     38
# 1     36
# 2     40
# 3     25
# 4     20
# 5     33
# 6     39
# 7     39
# 8     44
# 9     50
# 10    33
# 11    35
# 12    26
# 13    30
# 14    43
# 15    47
# 16    36
# 17    25
# 18    22
# 19    32
# 20    31
# 21    26
# 22    26
# 23    28
# 24    34
# 25    43
# 26    41
# 27    37
# 28    36
# 29    34
# 30    46
# Name: Temperature, dtype: int64

# %%
df2[['Temperature','Humidity']]
# Out:
#     Temperature  Humidity
# 0            38        52
# 1            36        46
# 2            40        47
# 3            25        44
# 4            20        41
# 5            33        35
# 6            39        33
# 7            39        64
# 8            44        77
# 9            50        71
# 10           33        37
# 11           35        53
# 12           26        42
# 13           30        47
# 14           43        62
# 15           47        70
# 16           36        66
# 17           25        53
# 18           22        42
# 19           32        49
# 20           31        45
# 21           26        41
# 22           26        78
# 23           28        53
# 24           34        54
# 25           43        56
# 26           41        45
# 27           37        51
# 28           36        50
# 29           34        46
# 30           46        52

# %%
df2.set_index("Temperature")
df2.head(3)
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  01-01-2016           38        23        52                 30.03
# 1  01-02-2016           36        18        46                 30.02
# 2  01-03-2016           40        21        47                 29.86
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277

# %%
df2.set_index("Temperature",inplace=True)
df2.head(3)
# Out:
#                     EST  DewPoint  Humidity  Sea Level PressureIn  \
# Temperature
# 38           01-01-2016        23        52                 30.03
# 36           01-02-2016        18        46                 30.02
# 40           01-03-2016        21        47                 29.86
#
#              VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# Temperature
# 38                        10           8.0               0           5    NaN
# 36                        10           7.0               0           3    NaN
# 40                        10           8.0               0           1    NaN
#
#              WindDirDegrees
# Temperature
# 38                      281
# 36                      275
# 40                      277

# %%
df2.reset_index(inplace=True)
df2.head(3)
# Out:
#    Temperature         EST  DewPoint  Humidity  Sea Level PressureIn  \
# 0           38  01-01-2016        23        52                 30.03
# 1           36  01-02-2016        18        46                 30.02
# 2           40  01-03-2016        21        47                 29.86
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277

# %%
type(df2['Humidity'])
# Out:
# pandas.core.series.Series

# %%
type(df2['EST'])
# Out:
# pandas.core.series.Series

# %%
df2['tempHum']=df2['Humidity']+df2['Temperature']

# %%
df2.head(2)
# Out:
#    Temperature         EST  DewPoint  Humidity  Sea Level PressureIn  \
# 0           38  01-01-2016        23        52                 30.03
# 1           36  01-02-2016        18        46                 30.02
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
#
#    WindDirDegrees  tempHum
# 0             281       90
# 1             275       82

# %%
df2.drop('tempHum',axis=1)
# Out:
#     Temperature         EST  DewPoint  Humidity  Sea Level PressureIn  \
# 0            38  01-01-2016        23        52                 30.03
# 1            36  01-02-2016        18        46                 30.02
# 2            40  01-03-2016        21        47                 29.86
# 3            25  01-04-2016         9        44                 30.05
# 4            20  01-05-2016        -3        41                 30.57
# 5            33  01-06-2016         4        35                 30.50
# 6            39  01-07-2016        11        33                 30.28
# 7            39  01-08-2016        29        64                 30.20
# 8            44  01-09-2016        38        77                 30.16
# 9            50  01-10-2016        46        71                 29.59
# 10           33  01-11-2016         8        37                 29.92
# 11           35  01-12-2016        15        53                 29.85
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Temperature           31 non-null     int64
#  1   EST                   31 non-null     object
#  2   DewPoint              31 non-null     int64
#  3   Humidity              31 non-null     int64
#  4   Sea Level PressureIn  31 non-null     float64
#  5   VisibilityMiles       31 non-null     int64
#  6   WindSpeedMPH          28 non-null     float64
#  7   PrecipitationIn       31 non-null     object
#  8   CloudCover            31 non-null     int64
#  9   Events                9 non-null      object
#  10  WindDirDegrees        31 non-null     int64
#  11  tempHum               31 non-null     int64
# dtypes: float64(2), int64(7), object(3)
# memory usage: 3.0+ KB

# %%
df2.drop('tempHum',axis=1,inplace=True)

# %%
df2.head(2)
# Out:
#    Temperature         EST  DewPoint  Humidity  Sea Level PressureIn  \
# 0           38  01-01-2016        23        52                 30.03
# 1           36  01-02-2016        18        46                 30.02
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
#
#    WindDirDegrees
# 0             281
# 1             275

# %%
df2.drop(1,axis=0,inplace=True)

# %%
df2.drop(3,axis=0,inplace=True)
df2.head(5)
# Out:
#    Temperature         EST  DewPoint  Humidity  Sea Level PressureIn  \
# 0           38  01-01-2016        23        52                 30.03
# 2           40  01-03-2016        21        47                 29.86
# 4           20  01-05-2016        -3        41                 30.57
# 5           33  01-06-2016         4        35                 30.50
# 6           39  01-07-2016        11        33                 30.28
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 2               10           8.0               0           1    NaN
# 4               10           5.0               0           0    NaN
# 5               10           4.0               0           0    NaN
# 6               10           2.0               0           3    NaN
#
#    WindDirDegrees
# 0             281
# 2             277
# 4             333
# 5             259
# 6             293

# %%
df2.head(4)
# Out:
#    Temperature         EST  DewPoint  Humidity  Sea Level PressureIn  \
# 0           38  01-01-2016        23        52                 30.03
# 2           40  01-03-2016        21        47                 29.86
# 4           20  01-05-2016        -3        41                 30.57
# 5           33  01-06-2016         4        35                 30.50
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 2               10           8.0               0           1    NaN
# 4               10           5.0               0           0    NaN
# 5               10           4.0               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 2             277
# 4             333
# 5             259

# %%
df2.loc[5]
# Out:
# Temperature                     33
# EST                     01-06-2016
# DewPoint                         4
# Humidity                        35
# Sea Level PressureIn          30.5
# VisibilityMiles                 10
# WindSpeedMPH                     4
# PrecipitationIn                  0
# CloudCover                       0
# Events                         NaN
# WindDirDegrees                 259
# Name: 5, dtype: object

# %%
df2.iloc[3]
# Out:
# Temperature                     33
# EST                     01-06-2016
# DewPoint                         4
# Humidity                        35
# Sea Level PressureIn          30.5
# VisibilityMiles                 10
# WindSpeedMPH                     4
# PrecipitationIn                  0
# CloudCover                       0
# Events                         NaN
# WindDirDegrees                 259
# Name: 5, dtype: object

# %%
print("Type:\n",type(df2))
# Out:
# Type:
#  <class 'pandas.core.frame.DataFrame'>

# %%
print("Shape of dataframe:",df2.shape)
df2.drop_duplicates()
print(df2.shape)
# Out:
# Shape of dataframe: (29, 11)
# (29, 11)

# %%
print("Columns of dataframe:\t",df2.columns)
# Out:
# Columns of dataframe:	 Index(['Temperature', 'EST', 'DewPoint', 'Humidity', 'Sea Level PressureIn',
#        'VisibilityMiles', 'WindSpeedMPH', 'PrecipitationIn', 'CloudCover',
#        'Events', 'WindDirDegrees'],
#       dtype='object')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29 entries, 0 to 30
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Temperature           29 non-null     int64
#  1   EST                   29 non-null     object
#  2   DewPoint              29 non-null     int64
#  3   Humidity              29 non-null     int64
#  4   Sea Level PressureIn  29 non-null     float64
#  5   VisibilityMiles       29 non-null     int64
#  6   WindSpeedMPH          26 non-null     float64
#  7   PrecipitationIn       29 non-null     object
#  8   CloudCover            29 non-null     int64
#  9   Events                9 non-null      object
#  10  WindDirDegrees        29 non-null     int64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 4.0+ KB

# %%
df2.rename(columns={'Events':'EventInfo'},inplace=True)
print("Columns of dataframe:\t",df2.columns)
# Out:
# Columns of dataframe:	 Index(['Temperature', 'EST', 'DewPoint', 'Humidity', 'Sea Level PressureIn',
#        'VisibilityMiles', 'WindSpeedMPH', 'PrecipitationIn', 'CloudCover',
#        'EventInfo', 'WindDirDegrees'],
#       dtype='object')

# %%
print(df2.describe())
# Out:
#        Temperature   DewPoint   Humidity  Sea Level PressureIn  \
# count    29.000000  29.000000  29.000000             29.000000
# mean     34.965517  18.137931  52.137931             29.990000
# std       7.683390  11.654932  11.897551              0.245255
# min      20.000000  -3.000000  33.000000             29.520000
# 25%      30.000000  11.000000  45.000000             29.850000
# 50%      35.000000  18.000000  51.000000             29.950000
# 75%      40.000000  23.000000  56.000000             30.150000
# max      50.000000  46.000000  78.000000             30.570000
#
#        VisibilityMiles  WindSpeedMPH  CloudCover  WindDirDegrees
# count        29.000000     26.000000   29.000000       29.000000
# mean          9.137931      6.807692    3.137931      242.793103
# std           1.995068      2.953225    2.721923       93.488494
# min           1.000000      2.000000    0.000000       34.000000
# 25%           9.000000      5.000000    1.000000      235.000000
# ...

# %%
print("First five values of 'Temperature' column\t:\n",df2.iloc[0:5,4:7])
# Out:
# First five values of 'Temperature' column	:
#     Sea Level PressureIn  VisibilityMiles  WindSpeedMPH
# 0                 30.03               10           8.0
# 2                 29.86               10           8.0
# 4                 30.57               10           5.0
# 5                 30.50               10           4.0
# 6                 30.28               10           2.0

# %%
df3 = df2['Temperature']>40
print(df3)
# Out:
# 0     False
# 2     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8      True
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 14     True
# 15     True
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25     True
# 26     True
# 27    False
# 28    False
# 29    False
# 30     True
# Name: Temperature, dtype: bool

# %%
df4 = df2[df3]
print(df4)
# Out:
#     Temperature         EST  DewPoint  Humidity  Sea Level PressureIn  \
# 8            44  01-09-2016        38        77                 30.16
# 9            50  01-10-2016        46        71                 29.59
# 14           43   1/15/2016        31        62                 29.82
# 15           47   1/16/2016        37        70                 29.52
# 25           43   1/26/2016        29        56                 30.03
# 26           41   1/27/2016        22        45                 30.03
# 30           46   1/31/2016        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover EventInfo  \
# 8                 9           8.0               T           8      Rain
# 9                 4           NaN             1.8           7      Rain
# 14                9           5.0               T           2       NaN
# 15                8           7.0            0.24           7      Rain
# ...

# %%
df5 = df2.groupby('EventInfo').mean()
df5
# Out:
#            Temperature   DewPoint  Humidity  Sea Level PressureIn  \
# EventInfo
# Fog-Snow     31.000000  22.000000     72.00             29.775000
# Rain         45.500000  35.750000     65.75             29.825000
# Snow         26.333333   7.666667     49.00             29.986667
#
#            VisibilityMiles  WindSpeedMPH  CloudCover  WindDirDegrees
# EventInfo
# Fog-Snow          4.500000     11.000000    7.000000           193.5
# Rain              7.750000      7.333333    6.250000           209.0
# Snow              8.666667      9.000000    2.666667           218.0

# %%
df2.plot(x='Temperature',y='Humidity',kind='scatter')
